# %%
pip install apyori
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from apyori import apriori

# %%
data=pd.read_csv("C:/Users/Asus/Downloads/archive (2)/columns.csv")
data
# Out:
#                               original                     short
# 0          I enjoy listening to music.                     Music
# 1                            I prefer.  Slow songs or fast songs
# 2                   Dance, Disco, Funk                     Dance
# 3                           Folk music                      Folk
# 4                              Country                   Country
# ..                                 ...                       ...
# 145                               I am       Left - right handed
# 146         Highest education achieved                 Education
# 147                I am the only child                Only child
# 148  I spent most of my childhood in a            Village - town
# 149  I lived most of my childhood in a    House - block of flats
#
# [150 rows x 2 columns]

# %%
data.shape
# Out:
# (150, 2)

# %%
records=[]
for i in range(0,150):
    records.append([str(data.values[i,j]) for j in range(0,2)])

# %%
for sets in records:
    print(sets)
# Out:
# ['I enjoy listening to music.', 'Music']
# ['I prefer.', 'Slow songs or fast songs']
# ['Dance, Disco, Funk', 'Dance']
# ['Folk music', 'Folk']
# ['Country', 'Country']
# ['Classical', 'Classical music']
# ['Musicals', 'Musical']
# ['Pop', 'Pop']
# ['Rock', 'Rock']
# ['Metal, Hard rock', 'Metal or Hardrock']
# ['Punk', 'Punk']
# ['Hip hop, Rap', 'Hiphop, Rap']
# ['Reggae, Ska', 'Reggae, Ska']
# ['Swing, Jazz', 'Swing, Jazz']
# ['Rock n Roll', 'Rock n roll']
# ['Alternative music', 'Alternative']
# ['Latin', 'Latino']
# ['Techno, Trance', 'Techno, Trance']
# ['Opera', 'Opera']
# ['I really enjoy watching movies.', 'Movies']
# ['Horror movies', 'Horror']
# ['Thriller movies', 'Thriller']
# ['Comedies', 'Comedy']
# ['Romantic movies', 'Romantic']
# ['Sci-fi movies', 'Sci-fi']
# ['War movies', 'War']
# ['Tales', 'Fantasy/Fairy tales']
# ['Cartoons', 'Animated']
# ['Documentaries', 'Documentary']
# ['Western movies', 'Western']
# ['Action movies', 'Action']
# ['History', 'History']
# ...

# %%
association_rules=apriori(records,min_support=0.5,min_confidence=0.7,min_length=2)

# %%
association_results=list(association_rules)

# %%
print(len(association_results))
# Out:
# 110

# %%
association_results[0]
# Out:
# RelationRecord(items=frozenset({'Achievements', 'I always let other people know about my achievements.'}), support=0.006666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Achievements'}), items_add=frozenset({'I always let other people know about my achievements.'}), confidence=1.0, lift=150.0), OrderedStatistic(items_base=frozenset({'I always let other people know about my achievements.'}), items_add=frozenset({'Achievements'}), confidence=1.0, lift=150.0)])

# %%
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    print("Rule :"+ str(item[0]) + "->" + str(item[1]))
    print("Support : {}".format(item[1]))
    print("Confidence : {}".format(item[2][0][2]))
    print("Lift : {}".format(item[2][0][3]))
    print("\n------------------------------------------------\n")
# Out:
# Rule :frozenset({'Achievements', 'I always let other people know about my achievements.'})->0.006666666666666667
# Support : 0.006666666666666667
# Confidence : 1.0
# Lift : 150.0
#
# ------------------------------------------------
#
# Rule :frozenset({'Action movies', 'Action'})->0.006666666666666667
# Support : 0.006666666666666667
# Confidence : 1.0
# Lift : 150.0
#
# ------------------------------------------------
#
# Rule :frozenset({'Sport at competitive level', 'Active sport'})->0.006666666666666667
# Support : 0.006666666666666667
# Confidence : 1.0
# Lift : 150.0
#
# ------------------------------------------------
#
# Rule :frozenset({'Drinking', 'Alcohol'})->0.006666666666666667
# Support : 0.006666666666666667
# Confidence : 1.0
# Lift : 150.0
#
# ------------------------------------------------
#
# Rule :frozenset({'Alternative music', 'Alternative'})->0.006666666666666667
# Support : 0.006666666666666667
# Confidence : 1.0
# Lift : 150.0
#
# ...
